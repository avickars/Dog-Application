# %%
import pandas as pd
import matplotlib.pyplot as plt
from kmeans import KMEANS
import numpy as np

# %%
trainLabels = pd.read_csv('open-images-v6/train/labels/detections.csv',index_col=0)

# %%
trainLabels['width'] = trainLabels['XMax'] - trainLabels['XMin']
trainLabels['height'] = trainLabels['YMax'] - trainLabels['YMin']

# %%
plt.title("Height v. Width")
plt.scatter(trainLabels['width'], trainLabels['height'], alpha=0.05)
plt.xlabel('Width')
plt.ylabel('Height')
plt.show()

# %%
boxes = trainLabels[['width','height']].values[0:10,:]

# %%
NUM_CLUSTERS = 20
avgIOU = []
for i in range(1, NUM_CLUSTERS+1):
    print('Num Clusters: ', i)
    clusters, centroids, meanCentroidIOU, num_iters = KMEANS(trainLabels[['width','height']].values, i, 150)
    print('Num Iters: ', num_iters)
    print('Avg IOU:', meanCentroidIOU)
    avgIOU.append(meanCentroidIOU)
    print('____________________________________')
# Out:
# Num Clusters:  1
# Num Iters:  2
# Avg IOU: 0.3989771848967215
# ____________________________________
# Num Clusters:  2
# Num Iters:  18
# Avg IOU: 0.5415370166998039
# ____________________________________
# Num Clusters:  3
# Num Iters:  24
# Avg IOU: 0.6123831450986974
# ____________________________________
# Num Clusters:  4
# Num Iters:  22
# Avg IOU: 0.6515386989789452
# ____________________________________
# Num Clusters:  5
# Num Iters:  51
# Avg IOU: 0.6700819229531109
# ____________________________________
# Num Clusters:  6
# Num Iters:  45
# Avg IOU: 0.6919771453953903
# ____________________________________
# Num Clusters:  7
# Num Iters:  85
# Avg IOU: 0.7084541067306492
# ____________________________________
# Num Clusters:  8
# Num Iters:  69
# Avg IOU: 0.720772006168173
# ____________________________________
# Num Clusters:  9
# Num Iters:  122
# Avg IOU: 0.7337567038791035
# ____________________________________
# Num Clusters:  10
# Num Iters:  85
# Avg IOU: 0.7430886701990822
# ____________________________________
# Num Clusters:  11
# Num Iters:  96
# Avg IOU: 0.751594499666365
# ____________________________________
# Num Clusters:  12
# Num Iters:  76
# Avg IOU: 0.7599536621847296
# ____________________________________
# Num Clusters:  13
# Num Iters:  60
# Avg IOU: 0.7667334851928141
# ____________________________________
# Num Clusters:  14
# Num Iters:  108
# Avg IOU: 0.774415074223982
# ____________________________________
# Num Clusters:  15
# Num Iters:  84
# Avg IOU: 0.7799519411395647
# ____________________________________
# Num Clusters:  16
# Num Iters:  147
# Avg IOU: 0.7858449825791385
# ____________________________________
# Num Clusters:  17
# Num Iters:  85
# Avg IOU: 0.7914397066331142
# ____________________________________
# Num Clusters:  18
# Num Iters:  150
# Avg IOU: 0.79499796149844
# ____________________________________
# Num Clusters:  19
# Num Iters:  127
# Avg IOU: 0.7989533450423175
# ____________________________________
# Num Clusters:  20
# Num Iters:  64
# Avg IOU: 0.8013411334749125
# ____________________________________

# %%
plt.title("Num Clusters v. Average IOU With Cluster Centroid")
plt.scatter(x=np.arange(1,NUM_CLUSTERS+1), y=avgIOU,marker='o')
plt.xlabel('Average IOU')
plt.ylabel('Num Clusters')
plt.show()

# %%
clusters, centroids, meanCentroidIOU, num_iters = KMEANS(trainLabels[['width','height']].values, 7, 150)

# %%
import seaborn as sns

trainLabels['Cluster'] = clusters

rgb_values = sns.color_palette("Set2", 7)

color_labels = trainLabels['Cluster'].unique()

color_map = dict(zip(color_labels, rgb_values))

plt.title("Clusters")
plt.scatter(trainLabels['width'], trainLabels['height'], c=trainLabels['Cluster'].map(color_map))
plt.xlabel('Width')
plt.ylabel('Height')
plt.show()

# %%
with open('centroids.npy', 'wb') as f:
    np.save(f, centroids)

# %%
with open('centroids.npy', 'rb') as f:
    centroids = np.load(f)
