# %%
# write your code
# ref: https://www.dataquest.io/blog/web-scraping-beautifulsoup/ 
# ref: https://www.dataquest.io/blog/web-scraping-python-using-beautiful-soup/ 
    
import requests
from requests import get
from bs4 import BeautifulSoup
import urllib.request # to download images
import re
import os # to make a directory
import csv

# %% [markdown]
# ## Initial Code to download dogs images and metadata from Petfinder from URLs that were saved in a separate txt file.

# %%
line_count = 1
f = open("pet_links.txt", "r")

for x in f:
    
    print("\n dog link details (line_count = ", line_count, "): \n")
    print(x, "\n")
    
    if(line_count > 1000):
        break

    link = x.rstrip('\n')
    
    page = requests.get(link)
    soup = BeautifulSoup(page.content, 'html.parser')

    dog_name = soup.find(attrs={"data-test" : "Pet_Name"})
    dog_name = re.sub('\s+', '', dog_name.contents[0]).lower() # remove \n, tabs and spaces from string

    images = []
    for image in soup.find_all('img'):
        images.append(image['src'])

    substring = '/'
    img_counter = 1
    unique_images = []

    for i in range(len(images)):
        substring = substring + str(img_counter) + "/" 
        if(substring in images[i]):
            unique_images.append(images[i])
        substring = '/'
        img_counter = img_counter + 1


    unique_dog_dir = ''
    unique_dog_dir = unique_dog_dir + dog_name

    dog_breed = soup.find(attrs={"data-test" : "Pet_Breeds"}).text.strip()

    unique_dog_dir = unique_dog_dir + '-' + dog_breed.lower().replace(" ", "-") # breed to dogname

    pet_location = soup.find(attrs={"data-test" : "Pet_Location"}).text.strip()

    dog_location =  pet_location.split(",")
    dog_city = dog_location[0]
    dog_state = dog_location[1]

    pet_location_dir = re.sub('\s+', '', pet_location).lower() # remove \n, tabs and spaces from string

    unique_dog_dir = unique_dog_dir + '-' + pet_location_dir.replace(",", "-") # location to dogname

    dog_location =  pet_location.split(",")
    dog_city = dog_location[0]
    dog_state = dog_location[1]

    dog_age = soup.find(attrs={"data-test" : "Pet_Age"}).text.strip()
    dog_sex = soup.find(attrs={"data-test" : "Pet_Sex"}).text.strip()
    dog_size = soup.find(attrs={"data-test" : "Pet_Full_Grown_Size"}).text.strip()


    print("dog_name: ", dog_name)
    print("dog_breed: ", dog_breed)

    print("dog_city: ", dog_city)
    print("dog_state: ", dog_state)
    print("unique_dog_dir: ", unique_dog_dir)

    print("dog_age: ", dog_age)
    print("dog_sex: ", dog_sex)
    print("dog_size: ", dog_size)

    unique_directory_counter = 1

    try:
        path = os.path.join("/Volumes/RK - T7/bd2_project_data/images/", unique_dog_dir)
        os.makedirs(path)
    except FileExistsError:
        # directory already exists - append unique num at the end of dir to make it unique
        path = os.path.join("/Volumes/RK - T7/bd2_project_data/images/", unique_dog_dir + '-' + str(unique_directory_counter))
        os.makedirs(path)
        unique_directory_counter = unique_directory_counter + 1
        pass

    # download dog's images in that unique directory
    unique_images_counter = 1
    for image_url in unique_images:
        # urllib.request.urlretrieve(image_url, "try_images/try.jpg")
        dog_image_name = dog_name + '-' + str(unique_images_counter) + ".jpg"
        dog_image_path = path + '/' + dog_image_name

        urllib.request.urlretrieve(image_url, dog_image_path)

        unique_images_counter = unique_images_counter + 1
        print(image_url)
        print(dog_image_path)

    #ref: https://www.pythontutorial.net/python-basics/python-write-csv-file/

    header = ['dog_name', 'dog_breed', 'dog_city', 'dog_state', 'unique_dog_dir', 'dog_age', 'dog_sex', 'dog_size', 'dog_images']
    data = [dog_name, dog_breed, dog_city, dog_state, unique_dog_dir, dog_age, dog_sex, dog_size, len(unique_images)]

    csv_file_name = dog_name + '.csv'

    with open(path + '/' + csv_file_name, 'w', encoding='UTF8') as f:
        writer = csv.writer(f)

        # write the header
        writer.writerow(header)

        # write the data
        writer.writerow(data)

    line_count = line_count + 1

f.close()
# Out:
#  dog link details (line_count =  1 ):
#
# dog_name:  laila
# dog_breed:  Pit Bull Terrier Mix
# dog_city:  Prince George
# dog_state:   BC
# unique_dog_dir:  laila-pit-bull-terrier-mix-princegeorge-bc
# dog_age:  Young
# dog_sex:  Female
# dog_size:  Medium
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54754243/1/?bust=1645813108&width=720
# /Volumes/RK - T7/bd2_project_data/images/laila-pit-bull-terrier-mix-princegeorge-bc/laila-1.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54754243/2/?bust=1645813108&width=720
# /Volumes/RK - T7/bd2_project_data/images/laila-pit-bull-terrier-mix-princegeorge-bc/laila-2.jpg
#
#  dog link details (line_count =  2 ):
#
# dog_name:  twinkle
# dog_breed:  German Shepherd Dog Mix
# dog_city:  Prince George
# dog_state:   BC
# unique_dog_dir:  twinkle-german-shepherd-dog-mix-princegeorge-bc
# dog_age:  Young
# dog_sex:  Female
# dog_size:  Medium
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54731090/1/?bust=1645744700&width=720
# /Volumes/RK - T7/bd2_project_data/images/twinkle-german-shepherd-dog-mix-princegeorge-bc/twinkle-1.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54731090/2/?bust=1645813184&width=720
# /Volumes/RK - T7/bd2_project_data/images/twinkle-german-shepherd-dog-mix-princegeorge-bc/twinkle-2.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54731090/3/?bust=1645813108&width=720
# /Volumes/RK - T7/bd2_project_data/images/twinkle-german-shepherd-dog-mix-princegeorge-bc/twinkle-3.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54731090/4/?bust=1645813183&width=720
# /Volumes/RK - T7/bd2_project_data/images/twinkle-german-shepherd-dog-mix-princegeorge-bc/twinkle-4.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54731090/5/?bust=1645813107&width=720
# /Volumes/RK - T7/bd2_project_data/images/twinkle-german-shepherd-dog-mix-princegeorge-bc/twinkle-5.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54731090/6/?bust=1645744702&width=720
# /Volumes/RK - T7/bd2_project_data/images/twinkle-german-shepherd-dog-mix-princegeorge-bc/twinkle-6.jpg
#
#  dog link details (line_count =  3 ):
#
# dog_name:  elizabeth
# dog_breed:  Norwegian Elkhound Mix
# dog_city:  Prince George
# dog_state:   BC
# unique_dog_dir:  elizabeth-norwegian-elkhound-mix-princegeorge-bc
# dog_age:  Young
# dog_sex:  Female
# dog_size:  Medium
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54712052/1/?bust=1645744698&width=720
# /Volumes/RK - T7/bd2_project_data/images/elizabeth-norwegian-elkhound-mix-princegeorge-bc/elizabeth-1.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54712052/2/?bust=1645744699&width=720
# /Volumes/RK - T7/bd2_project_data/images/elizabeth-norwegian-elkhound-mix-princegeorge-bc/elizabeth-2.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/
jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54662455/6/?bust=1645647668&width=720
# /Volumes/RK - T7/bd2_project_data/images/skya-alaskan-malamute-mix-dawsoncreek-bc/skya-6.jpg
#
#  dog link details (line_count =  7 ):
#
# dog_name:  mocha
# dog_breed:  Labrador Retriever Mix
# dog_city:  Whistler
# dog_state:   BC
# unique_dog_dir:  mocha-labrador-retriever-mix-whistler-bc
# dog_age:  Young
# dog_sex:  Male
# dog_size:  Large
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/53659226/1/?bust=1645517442&width=720
# /Volumes/RK - T7/bd2_project_data/images/mocha-labrador-retriever-mix-whistler-bc/mocha-1.jpg
#
#  dog link details (line_count =  8 ):
#
# dog_name:  caelum
# dog_breed:  Labrador Retriever Mix
# dog_city:  Whistler
# dog_state:   BC
# unique_dog_dir:  caelum-labrador-retriever-mix-whistler-bc
# dog_age:  Adult
# dog_sex:  Male
# dog_size:  Large
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/52421265/1/?bust=1645517442&width=720
# /Volumes/RK - T7/bd2_project_data/images/caelum-labrador-retriever-mix-whistler-bc/caelum-1.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/52421265/2/?bust=1645517442&width=720
# /Volumes/RK - T7/bd2_project_data/images/caelum-labrador-retriever-mix-whistler-bc/caelum-2.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/52421265/3/?bust=1645517443&width=720
# /Volumes/RK - T7/bd2_project_data/images/caelum-labrador-retriever-mix-whistler-bc/caelum-3.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/52421265/4/?bust=1645517443&width=720
# /Volumes/RK - T7/bd2_project_data/images/caelum-labrador-retriever-mix-whistler-bc/caelum-4.jpg
#
#  dog link details (line_count =  9 ):
#
# dog_name:  sol
# dog_breed:  Labrador Retriever Mix
# dog_city:  Whistler
# dog_state:   BC
# unique_dog_dir:  sol-labrador-retriever-mix-whistler-bc
# dog_age:  Adult
# dog_sex:  Male
# dog_size:  Large
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/52421267/1/?bust=1645517443&width=720
# /Volumes/RK - T7/bd2_project_data/images/sol-labrador-retriever-mix-whistler-bc/sol-1.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/52421267/2/?bust=1645517443&width=720
# /Volumes/RK - T7/bd2_project_data/images/sol-labrador-retriever-mix-whistler-bc/sol-2.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/52421267/3/?bust=1645517448&width=720
# /Volumes/RK - T7/bd2_project_data/images/sol-labrador-retriever-mix-whistler-bc/sol-3.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/52421267/4/?bust=1645517448&width=720
# /Volumes/RK - T7/bd2_project_data/images/sol-labrador-retriever-mix-whistler-bc/sol-4.jpg
#
#  dog link details (line_count =  10 ):
#
# dog_name:  lola
# dog_breed:  Pit Bull Terrier
# dog_city:  Whistler
# dog_state:   BC
# unique_dog_dir:  lola-pit-bull-terrier-whistler-bc
# dog_age:  Young
# dog_sex:  Female
# dog_size:  Medium
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/42601095/6/?bust=1546886904&width=720
# /Volumes/RK - T7/bd2_project_data/images/lola-pit-bull-terrier-whistler-bc/lola-1.jpg
#
#  dog link details (line_count =  11 ):
#
# dog_name:  lily
# dog_breed:  Labrador Retriever & Australian Kelpie Mix
# dog_city:  Powell River
# dog_state:   BC
# unique_dog_dir:  lily-labrador-retriever-&-australian-kelpie-mix-powellriver-bc
# dog_age:  Young
# dog_sex:  Female
# dog_size:  Medium
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/
jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54480432/4/?bust=1645425249&width=720
# /Volumes/RK - T7/bd2_project_data/images/buddy-labrador-retriever-mix-salmonarm-bc/buddy-4.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54480432/5/?bust=1645425209&width=720
# /Volumes/RK - T7/bd2_project_data/images/buddy-labrador-retriever-mix-salmonarm-bc/buddy-5.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54480432/6/?bust=1645425172&width=720
# /Volumes/RK - T7/bd2_project_data/images/buddy-labrador-retriever-mix-salmonarm-bc/buddy-6.jpg
#
#  dog link details (line_count =  44 ):
#
# dog_name:  remy
# dog_breed:  Pit Bull Terrier
# dog_city:  North Vancouver
# dog_state:   BC
# unique_dog_dir:  remy-pit-bull-terrier-northvancouver-bc
# dog_age:  Adult
# dog_sex:  Male
# dog_size:  Large
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54748155/1/?bust=1645764545&width=720
# /Volumes/RK - T7/bd2_project_data/images/remy-pit-bull-terrier-northvancouver-bc/remy-1.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54748155/2/?bust=1645764545&width=720
# /Volumes/RK - T7/bd2_project_data/images/remy-pit-bull-terrier-northvancouver-bc/remy-2.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54748155/3/?bust=1645764546&width=720
# /Volumes/RK - T7/bd2_project_data/images/remy-pit-bull-terrier-northvancouver-bc/remy-3.jpg
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54748155/4/?bust=1645764546&width=720
# /Volumes/RK - T7/bd2_project_data/images/remy-pit-bull-terrier-northvancouver-bc/remy-4.jpg
#
#  dog link details (line_count =  45 ):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-58e1a3effdb8> in <module>
#      15
#      16     dog_name = soup.find(attrs={"data-test" : "Pet_Name"})
# ---> 17     dog_name = re.sub('\s+', '', dog_name.contents[0]).lower() # remove \n, tabs and spaces from string
#      18
#      19     images = []
#
# AttributeError: 'NoneType' object has no attribute 'contents'

# %% [markdown]
# # Fix page not available error
#
# **Example URL (line_number 45):** <br>
# https://www.petfinder.com/dog/johnny-54711544/bc/north-vancouver/heart-of-the-underdog-tx2483/'
#
# ---> 17     dog_name = re.sub('\s+', '', dog_name.contents[0]).lower() # remove \n, tabs and spaces from string
#      18
#      19     images = []
#
# AttributeError: 'NoneType' object has no attribute 'contents'

# %%
# ref: https://stackoverflow.com/questions/2081836/how-to-read-specific-lines-from-a-file-by-line-number

f = open("pet_links.txt", "r")
for line_count, line in enumerate(f):
    if line_count == 48:
        break
        
    elif line_count >= 44:
        print("line_count: ", line_count)
        print("line: ", line)
        
f.close()
# Out:
# line_count:  44
# line:  https://www.petfinder.com/dog/johnny-54711544/bc/north-vancouver/heart-of-the-underdog-tx2483/
#
# line_count:  45
# line:  https://www.petfinder.com/dog/june-54711285/bc/north-vancouver/heart-of-the-underdog-tx2483/
#
# line_count:  46
# line:  https://www.petfinder.com/dog/winx-54709948/bc/north-vancouver/dizzy-dog-animal-rescue-nc1172/
#
# line_count:  47
# line:  https://www.petfinder.com/dog/ramses-54708166/bc/north-vancouver/heart-of-the-underdog-tx2483/

# %%
# ref: https://stackoverflow.com/questions/2081836/how-to-read-specific-lines-from-a-file-by-line-number

f = open("pet_links.txt", "r")

for line_count, line in enumerate(f):
    
    if(line_count == 1000):
        break
        
    # line_count starts from 0, so 45th line would be when line_count = 44 
    elif line_count >= 44:
        
        print("\n dog link details (line_count = ", line_count, "): \n")
        print(line, "\n")

        # strip \n from the end of the link
        link = line.rstrip('\n')

        page = requests.get(link)
        
        # if dog page is no longer available (404 or 500), continue to next doge page link
        if((page.status_code//100 == 4) or (page.status_code//100 == 5)):
            print("dog page no longer available, skip it \n")
            continue
            
        soup = BeautifulSoup(page.content, 'html.parser')

        dog_name = soup.find(attrs={"data-test" : "Pet_Name"})
        dog_name = re.sub('\s+', '', dog_name.contents[0]).lower() # remove \n, tabs and spaces from string

        images = []
        for image in soup.find_all('img'):
            images.append(image['src'])

        substring = '/'
        img_counter = 1
        unique_images = []

        for i in range(len(images)):
            substring = substring + str(img_counter) + "/" 
            if(substring in images[i]):
                unique_images.append(images[i])
            substring = '/'
            img_counter = img_counter + 1


        unique_dog_dir = ''
        unique_dog_dir = unique_dog_dir + dog_name

        dog_breed = soup.find(attrs={"data-test" : "Pet_Breeds"}).text.strip()

        unique_dog_dir = unique_dog_dir + '-' + dog_breed.lower().replace(" ", "-") # breed to dogname

        pet_location = soup.find(attrs={"data-test" : "Pet_Location"}).text.strip()

        dog_location =  pet_location.split(",")
        dog_city = dog_location[0]
        dog_state = dog_location[1]

        pet_location_dir = re.sub('\s+', '', pet_location).lower() # remove \n, tabs and spaces from string

        unique_dog_dir = unique_dog_dir + '-' + pet_location_dir.replace(",", "-") # location to dogname

        dog_location =  pet_location.split(",")
        dog_city = dog_location[0]
        dog_state = dog_location[1]

        dog_age = soup.find(attrs={"data-test" : "Pet_Age"}).text.strip()
        dog_sex = soup.find(attrs={"data-test" : "Pet_Sex"}).text.strip()
        dog_size = soup.find(attrs={"data-test" : "Pet_Full_Grown_Size"}).text.strip()


        print("dog_name: ", dog_name)
        print("dog_breed: ", dog_breed)

        print("dog_city: ", dog_city)
        print("dog_state: ", dog_state)
        print("unique_dog_dir: ", unique_dog_dir)

        print("dog_age: ", dog_age)
        print("dog_sex: ", dog_sex)
        print("dog_size: ", dog_size)

        unique_directory_counter = 1

        try:
            path = os.path.join("/Volumes/RK - T7/bd2_project_data/images/", unique_dog_dir)
            os.makedirs(path)
        except FileExistsError:
            # directory already exists - append unique num at the end of dir to make it unique
            path = os.path.join("/Volumes/RK - T7/bd2_project_data/images/", unique_dog_dir + '-' + str(unique_directory_counter))
            os.makedirs(path)
            unique_directory_counter = unique_directory_counter + 1
            pass

        # download dog's images in that unique directory
        unique_images_counter = 1
        for image_url in unique_images:
            # urllib.request.urlretrieve(image_url, "try_images/try.jpg")
            dog_image_name = dog_name + '-' + str(unique_images_counter) + ".jpg"
            dog_image_path = path + '/' + dog_image_name

            urllib.request.urlretrieve(image_url, dog_image_path)

            unique_images_counter = unique_images_counter + 1
            print(image_url)
            print(dog_image_path)

        #ref: https://www.pythontutorial.net/python-basics/python-write-csv-file/

        header = ['dog_name', 'dog_breed', 'dog_city', 'dog_state', 'unique_dog_dir', 'dog_age', 'dog_sex', 'dog_size', 'dog_images']
        data = [dog_name, dog_breed, dog_city, dog_state, unique_dog_dir, dog_age, dog_sex, dog_size, len(unique_images)]

        csv_file_name = dog_name + '.csv'

        with open(path + '/' + csv_file_name, 'w', encoding='UTF8') as f:
            writer = csv.writer(f)

            # write the header
            writer.writerow(header)

            # write the data
            writer.writerow(data)

f.close()

# %% [markdown]
# # Fix Unsupported Media Type error when downloading images
#
# ### HTTPError: HTTP Error 415: Unsupported Media Type
#
#
# **Example dog URL (line_number 90):** <br>
# https://www.petfinder.com/dog/betty-is-ready-to-adopt-54409062/bc/vancouver/vancouver-shar-pei-rescue-bc199/
#
# **Example image URL that gives error** <br>
# https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/54409062/5/?bust=1645555664&width=1080'

# %%
try:
    urllib.request.urlretrieve(image_url, dog_image_path)

except:
    # HTTPError: HTTP Error 415: Unsupported Media Type
    print(image_url)
    print("HTTPError: HTTP Error 415: Unsupported Media Type, \ncontinue to next image")
    
    pass

# %%
# ref: https://stackoverflow.com/questions/2081836/how-to-read-specific-lines-from-a-file-by-line-number

f = open("pet_links.txt", "r")

for line_count, line in enumerate(f):
    
    if(line_count == 1000):
        break
        
    # line_count starts from 0, so 45th line would be when line_count = 44 
    elif line_count >= 90:
        
        print("\n dog link details (line_count = ", line_count, "): \n")
        print(line, "\n")

        # strip \n from the end of the link
        link = line.rstrip('\n')

        page = requests.get(link)
        
        # if dog page is no longer available (404 or 500), continue to next doge page link
        if((page.status_code//100 == 4) or (page.status_code//100 == 5)):
            print("dog page no longer available, skip it \n")
            continue
            
        soup = BeautifulSoup(page.content, 'html.parser')

        dog_name = soup.find(attrs={"data-test" : "Pet_Name"})
        dog_name = re.sub('\s+', '', dog_name.contents[0]).lower() # remove \n, tabs and spaces from string

        images = []
        for image in soup.find_all('img'):
            images.append(image['src'])

        substring = '/'
        img_counter = 1
        unique_images = []

        for i in range(len(images)):
            substring = substring + str(img_counter) + "/" 
            if(substring in images[i]):
                unique_images.append(images[i])
            substring = '/'
            img_counter = img_counter + 1


        unique_dog_dir = ''
        unique_dog_dir = unique_dog_dir + dog_name

        dog_breed = soup.find(attrs={"data-test" : "Pet_Breeds"}).text.strip()

        unique_dog_dir = unique_dog_dir + '-' + dog_breed.lower().replace(" ", "-") # breed to dogname

        pet_location = soup.find(attrs={"data-test" : "Pet_Location"}).text.strip()

        dog_location =  pet_location.split(",")
        dog_city = dog_location[0]
        dog_state = dog_location[1]

        pet_location_dir = re.sub('\s+', '', pet_location).lower() # remove \n, tabs and spaces from string

        unique_dog_dir = unique_dog_dir + '-' + pet_location_dir.replace(",", "-") # location to dogname

        dog_location =  pet_location.split(",")
        dog_city = dog_location[0]
        dog_state = dog_location[1]

        dog_age = soup.find(attrs={"data-test" : "Pet_Age"}).text.strip()
        dog_sex = soup.find(attrs={"data-test" : "Pet_Sex"}).text.strip()
        dog_size = soup.find(attrs={"data-test" : "Pet_Full_Grown_Size"}).text.strip()


        print("dog_name: ", dog_name)
        print("dog_breed: ", dog_breed)

        print("dog_city: ", dog_city)
        print("dog_state: ", dog_state)
        print("unique_dog_dir: ", unique_dog_dir)

        print("dog_age: ", dog_age)
        print("dog_sex: ", dog_sex)
        print("dog_size: ", dog_size)

        unique_directory_counter = 1

        try:
            path = os.path.join("/Volumes/RK - T7/bd2_project_data/images/", unique_dog_dir)
            os.makedirs(path)
        except FileExistsError:
            # directory already exists - append unique num at the end of dir to make it unique
            path = os.path.join("/Volumes/RK - T7/bd2_project_data/images/", unique_dog_dir + '-' + str(unique_directory_counter))
            os.makedirs(path)
            unique_directory_counter = unique_directory_counter + 1
            pass

        # download dog's images in that unique directory
        unique_images_counter = 1
        for image_url in unique_images:
            # urllib.request.urlretrieve(image_url, "try_images/try.jpg")
            dog_image_name = dog_name + '-' + str(unique_images_counter) + ".jpg"
            dog_image_path = path + '/' + dog_image_name
            
            print(image_url)
            print(dog_image_path)

            try:
                urllib.request.urlretrieve(image_url, dog_image_path)
                unique_images_counter = unique_images_counter + 1

            except:
                # HTTPError: HTTP Error 415: Unsupported Media Type
                print(image_url)
                print("HTTPError: HTTP Error 415: Unsupported Media Type, \ncontinue to next image")

                pass


        #ref: https://www.pythontutorial.net/python-basics/python-write-csv-file/

        header = ['dog_name', 'dog_breed', 'dog_city', 'dog_state', 'unique_dog_dir', 'dog_age', 'dog_sex', 'dog_size', 'dog_images']
        data = [dog_name, dog_breed, dog_city, dog_state, unique_dog_dir, dog_age, dog_sex, dog_size, len(unique_images)]

        csv_file_name = dog_name + '.csv'

        with open(path + '/' + csv_file_name, 'w', encoding='UTF8') as f:
            writer = csv.writer(f)

            # write the header
            writer.writerow(header)

            # write the data
            writer.writerow(data)

f.close()

# %% [markdown]
# # Error - if the dog name has /, it causes issues with the path name
#
# **example dog_name = mocha/oreo <br>
# dog link details (line_count =  156 ):**
#
# https://www.petfinder.com/dog/mocha-oreo-54610670/bc/surrey/pawz-patrol-bc266/
#
#
# dog_name:  mocha/oreo <br>
# dog_breed:  Chihuahua
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/RK - T7/bd2_project_data/images/mocha/oreo-chihuahua-surrey-bc/mocha/oreo.csv'

# %%
dog_name = 'mocha/oreo'

dog_name
# Out:
# 'mocha/oreo'

# %%
if "/" in dog_name: 
    dog_name = dog_name.replace("/", "-") 
    
dog_name
# Out:
# 'mocha-oreo'

# %%
# ref: https://stackoverflow.com/questions/2081836/how-to-read-specific-lines-from-a-file-by-line-number

f = open("pet_links.txt", "r")

for line_count, line in enumerate(f):
    
    if(line_count == 1000):
        break
        
    # line_count starts from 0, so 45th line would be when line_count = 44 
    elif line_count >= 90:
        
        print("\n dog link details (line_count = ", line_count, "): \n")
        print(line, "\n")

        # strip \n from the end of the link
        link = line.rstrip('\n')

        page = requests.get(link)
        
        # if dog page is no longer available (404 or 500), continue to next doge page link
        if((page.status_code//100 == 4) or (page.status_code//100 == 5)):
            print("dog page no longer available, skip it \n")
            continue
            
        soup = BeautifulSoup(page.content, 'html.parser')

        dog_name = soup.find(attrs={"data-test" : "Pet_Name"})
        dog_name = re.sub('\s+', '', dog_name.contents[0]).lower() # remove \n, tabs and spaces from string
        
        # dog_name has /, replace it with -
        if "/" in dog_name: 
            dog_name = dog_name.replace("/", "-") 

        images = []
        for image in soup.find_all('img'):
            images.append(image['src'])

        substring = '/'
        img_counter = 1
        unique_images = []

        for i in range(len(images)):
            substring = substring + str(img_counter) + "/" 
            if(substring in images[i]):
                unique_images.append(images[i])
            substring = '/'
            img_counter = img_counter + 1


        unique_dog_dir = ''
        unique_dog_dir = unique_dog_dir + dog_name

        dog_breed = soup.find(attrs={"data-test" : "Pet_Breeds"}).text.strip()

        unique_dog_dir = unique_dog_dir + '-' + dog_breed.lower().replace(" ", "-") # breed to dogname

        pet_location = soup.find(attrs={"data-test" : "Pet_Location"}).text.strip()

        dog_location =  pet_location.split(",")
        dog_city = dog_location[0]
        dog_state = dog_location[1]

        pet_location_dir = re.sub('\s+', '', pet_location).lower() # remove \n, tabs and spaces from string

        unique_dog_dir = unique_dog_dir + '-' + pet_location_dir.replace(",", "-") # location to dogname

        dog_location =  pet_location.split(",")
        dog_city = dog_location[0]
        dog_state = dog_location[1]

        dog_age = soup.find(attrs={"data-test" : "Pet_Age"}).text.strip()
        dog_sex = soup.find(attrs={"data-test" : "Pet_Sex"}).text.strip()
        dog_size = soup.find(attrs={"data-test" : "Pet_Full_Grown_Size"}).text.strip()


        print("dog_name: ", dog_name)
        print("dog_breed: ", dog_breed)

        print("dog_city: ", dog_city)
        print("dog_state: ", dog_state)
        print("unique_dog_dir: ", unique_dog_dir)

        print("dog_age: ", dog_age)
        print("dog_sex: ", dog_sex)
        print("dog_size: ", dog_size)

        unique_directory_counter = 1

        try:
            path = os.path.join("/Volumes/RK - T7/bd2_project_data/images/", unique_dog_dir)
            os.makedirs(path)
        except FileExistsError:
            # directory already exists - append unique num at the end of dir to make it unique
            path = os.path.join("/Volumes/RK - T7/bd2_project_data/images/", unique_dog_dir + '-' + str(unique_directory_counter))
            os.makedirs(path)
            unique_directory_counter = unique_directory_counter + 1
            pass

        # download dog's images in that unique directory
        unique_images_counter = 1
        for image_url in unique_images:
            # urllib.request.urlretrieve(image_url, "try_images/try.jpg")
            dog_image_name = dog_name + '-' + str(unique_images_counter) + ".jpg"
            dog_image_path = path + '/' + dog_image_name
            
            print(image_url)
            print(dog_image_path)

            try:
                urllib.request.urlretrieve(image_url, dog_image_path)
                unique_images_counter = unique_images_counter + 1

            except:
                # HTTPError: HTTP Error 415: Unsupported Media Type
                print(image_url)
                print("HTTPError: HTTP Error 415: Unsupported Media Type, \ncontinue to next image")

                pass


        #ref: https://www.pythontutorial.net/python-basics/python-write-csv-file/

        header = ['dog_name', 'dog_breed', 'dog_city', 'dog_state', 'unique_dog_dir', 'dog_age', 'dog_sex', 'dog_size', 'dog_images']
        data = [dog_name, dog_breed, dog_city, dog_state, unique_dog_dir, dog_age, dog_sex, dog_size, len(unique_images)]

        csv_file_name = dog_name + '.csv'

        with open(path + '/' + csv_file_name, 'w', encoding='UTF8') as f:
            writer = csv.writer(f)

            # write the header
            writer.writerow(header)

            # write the data
            writer.writerow(data)

f.close()
